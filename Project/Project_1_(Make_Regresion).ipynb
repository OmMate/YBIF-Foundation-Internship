# %%
from sklearn.datasets import make_regression

# %%
#noise= the differences in the values of features
#bias = divides the target into number of parts to analyze
#returns X,y,z which are features, target and coefficient of linear model
# z is returned only when coef= True

# %%
from numpy.random.mtrand import shuffle
X,y,z=make_regression(n_samples=100,coef=True,noise=15,bias=100,
                      shuffle=True,random_state=1,n_features=1,n_targets=1)

# %%
X.shape,y.shape
# Out:
# ((100, 1), (100,))

# %%
z
# Out:
# array(80.71051956)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y,c=y,edgecolor='k')

# c parameter is the array of colours and edgecolor decides color of border of marker
